# %% [markdown]
# <a href="https://colab.research.google.com/github/kummariBharath/Seasonal_Agriculture_Performance_Analysis/blob/main/Seasonal_Agriculture_Performance_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Seasonal Agriculture Performance Analysis
#
# ## Project Overview
#
# This project analyzes agricultural performance across different crops, seasons, and states.
#
# The analysis focuses on:
# - Crop yield and production
# - Seasonal performance
# - State-level performance
# - Revenue, cost, and profit
# - Water efficiency
# - Disease and pest risk
# - Correlations between agricultural variables
#
# ## Objectives
#
# 1. Identify high- and low-performing crops.
# 2. Compare agricultural performance across seasons.
# 3. Compare yield across states.
# 4. Analyze crop profitability.
# 5. Evaluate water efficiency.
# 6. Identify disease and pest risk patterns.
# 7. Discover relationships between important agricultural variables.
# 8. Generate insights and recommendations from the data.
#
# ## Tools & Technologies
#
# - Python
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# - Google Colab
# - Excel dataset

# %%
import pandas as pd
df = pd.read_excel("seasonal_agriculture_performance_dataset.xlsx")

# %%
df.head() #head() gives us the first 5 rows
# Out:
#    Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 0  SF10001  Andhra Pradesh    Rajkot   Wheat  Kharif                0.53
# 1  SF10002     Maharashtra  Nalgonda   Maize  Kharif                6.53
# 2  SF10003       Telangana  Warangal  Pulses    Rabi                4.86
# 3  SF10004       Telangana    Indore    Rice  Kharif                4.50
# 4  SF10005       Karnataka  Ludhiana   Maize    Zaid                4.21
#
#    Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  ...  \
# 0        486.4               24.3          69.1                 5.8  ...
# 1        855.4               25.7          78.4                 5.1  ...
# 2        455.6               23.9          56.4                10.3  ...
# 3        753.2               29.7          65.2                 6.3  ...
# 4        101.6               34.1          55.2                 6.5  ...
#
#    Seed_Quality_Score  Yield_Tonnes_Ha  Production_Tonnes  \
# ...

# %%
df.head(10)#head(10) gives us the first 10 rows
# Out:
#    Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 0  SF10001  Andhra Pradesh    Rajkot   Wheat  Kharif                0.53
# 1  SF10002     Maharashtra  Nalgonda   Maize  Kharif                6.53
# 2  SF10003       Telangana  Warangal  Pulses    Rabi                4.86
# 3  SF10004       Telangana    Indore    Rice  Kharif                4.50
# 4  SF10005       Karnataka  Ludhiana   Maize    Zaid                4.21
# 5  SF10006         Gujarat   Raichur  Pulses    Zaid                5.46
# 6  SF10007       Telangana  Warangal   Wheat    Rabi                8.13
# 7  SF10008      Tamil Nadu  Ludhiana  Pulses  Kharif                5.34
# 8  SF10009       Karnataka    Guntur  Cotton    Zaid                6.98
# 9  SF10010      Tamil Nadu   Raichur  Chilli    Rabi               13.69
#
#    Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  ...  \
# 0        486.4               24.3          69.1                 5.8  ...
# ...

# %%
df.shape #how big is the dataset (rows,columns)
# Out:
# (4000, 28)

# %%
df.columns
# Out:
# Index(['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Farm_Area_Hectares',
#        'Rainfall_mm', 'Avg_Temperature_C', 'Humidity_pct',
#        'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct', 'Nitrogen_kg_ha',
#        'Phosphorus_kg_ha', 'Potassium_kg_h', 'Irrigation_Method',
#        'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score',
#        'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne',
#        'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3',
#        'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct'],
#       dtype='object')

# %%
df.info() #tells about Column names--Number of non-null values,Data types,Memory usage int64(whole),float64(decimal),object(text/categories)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Farm_ID                        4000 non-null   object
#  1   State                          4000 non-null   object
#  2   District                       4000 non-null   object
#  3   Crop                           4000 non-null   object
#  4   Season                         4000 non-null   object
#  5   Farm_Area_Hectares             4000 non-null   float64
#  6   Rainfall_mm                    3952 non-null   float64
#  7   Avg_Temperature_C              4000 non-null   float64
#  8   Humidity_pct                   4000 non-null   float64
#  9   Sunlight_Hours_Day             4000 non-null   float64
#  10  Soil_pH                        4000 non-null   float64
#  11  Soil_Moisture_pct              3960 non-null   float64
# ...

# %%
df.isnull().sum() #missing values are present in each column
# Out:
# Farm_ID                           0
# State                             0
# District                          0
# Crop                              0
# Season                            0
# Farm_Area_Hectares                0
# Rainfall_mm                      48
# Avg_Temperature_C                 0
# Humidity_pct                      0
# Sunlight_Hours_Day                0
# Soil_pH                           0
# Soil_Moisture_pct                40
# Nitrogen_kg_ha                    0
# Phosphorus_kg_ha                  0
# Potassium_kg_h                    0
# Irrigation_Method                 0
# Fertilizer_kg_ha                  0
# Pesticide_Litre_ha                0
# Seed_Quality_Score                0
# Yield_Tonnes_Ha                  32
# Production_Tonnes                 0
# Market_Price_INR_Tonne            0
# Total_Cost_INR                    0
# Revenue_INR                       0
# Profit_INR                        0
# Water_Used_m3                     0
# ...

# %%
df.duplicated().sum() #tells about dulplicate rows
# Out:
# np.int64(0)

# %%
print("States:")                                   #unique() method tells about the unique values in the column
print(df["State"].unique())

print("\nCrops:")
print(df["Crop"].unique())

print("\nSeasons:")
print(df["Season"].unique())

print("\nIrrigation Methods:")
print(df["Irrigation_Method"].unique())
# Out:
# States:
# ['Andhra Pradesh' 'Maharashtra' 'Telangana' 'Karnataka' 'Gujarat'
#  'Tamil Nadu' 'Punjab' 'Madhya Pradesh']
#
# Crops:
# ['Wheat' 'Maize' 'Pulses' 'Rice' 'Cotton' 'Chilli' 'Groundnut' 'Sugarcane']
#
# Seasons:
# ['Kharif' 'Rabi' 'Zaid']
#
# Irrigation Methods:
# ['Drip' 'Flood' 'Rainfed' 'Sprinkler']

# %%
df["Season"].value_counts() #tells us How many farming records do we have for each season
# Out:
# Season
# Kharif    1779
# Rabi      1627
# Zaid       594
# Name: count, dtype: int64

# %%
df["Season"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Season'>

# %%
df["Crop"].value_counts() #tells how many records we have for each crop
# Out:
# Crop
# Rice         690
# Wheat        614
# Maize        551
# Cotton       508
# Pulses       496
# Groundnut    424
# Chilli       412
# Sugarcane    305
# Name: count, dtype: int64

# %%
df["Crop"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Crop'>

# %%
df.describe() #tells about count,Number of available values,Average,Standard deviation,Minimum,25th percentile,(50%)Median,75th percentilema
# Out:
#        Farm_Area_Hectares  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# count         4000.000000  3952.000000         4000.00000   4000.000000
# mean             7.888265   601.152657           26.81890     63.210500
# std              4.223764   288.925025            3.81818     11.960834
# min              0.500000    80.000000           16.20000     25.000000
# 25%              4.260000   370.200000           23.90000     54.775000
# 50%              7.895000   582.000000           26.90000     63.000000
# 75%             11.650000   834.950000           29.60000     71.900000
# max             15.000000  1395.200000           39.70000     95.000000
#
#        Sunlight_Hours_Day      Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  \
# count         4000.000000  4000.000000        3960.000000     4000.000000
# mean             7.323050     6.701010          26.508232      120.250825
# std              1.121186     0.641461           6.712484       31.216452
# ...

# %% [markdown]
# ##Dataset Understanding
#
# The dataset contains 4,000 agricultural records and 28 variables. It includes information about farm location, crops, seasons, environmental conditions, soil characteristics, farming inputs, resource usage, agricultural production, and economic performance.
#
# For this analysis, the variables can be broadly grouped into:
#
# - **Farm and geographical information:** State, District, Crop, Season
# - **Environmental conditions:** Rainfall, temperature, humidity, and sunlight
# - **Soil conditions:** Soil pH and soil moisture
# - **Agricultural inputs:** Nitrogen, phosphorus, potassium, fertilizer, pesticide, and seed quality
# - **Resource usage:** Irrigation method, water usage, and water efficiency
# - **Agricultural performance:** Yield, production, revenue, and profit
# - **Risk:** Disease and pest risk

# %%
# Display the data type of every column

df.dtypes
# Out:
# Farm_ID                           object
# State                             object
# District                          object
# Crop                              object
# Season                            object
# Farm_Area_Hectares               float64
# Rainfall_mm                      float64
# Avg_Temperature_C                float64
# Humidity_pct                     float64
# Sunlight_Hours_Day               float64
# Soil_pH                          float64
# Soil_Moisture_pct                float64
# Nitrogen_kg_ha                   float64
# Phosphorus_kg_ha                 float64
# Potassium_kg_h                   float64
# Irrigation_Method                 object
# Fertilizer_kg_ha                 float64
# Pesticide_Litre_ha               float64
# Seed_Quality_Score               float64
# Yield_Tonnes_Ha                  float64
# Production_Tonnes                float64
# Market_Price_INR_Tonne             int64
# Total_Cost_INR                     int64
# ...

# %%
# Separate numerical and categorical columns

numerical_columns = df.select_dtypes(include="number").columns
categorical_columns = df.select_dtypes(include="object").columns

print("Numerical Columns:")
print(numerical_columns)

print("\nCategorical Columns:")
print(categorical_columns)
# Out:
# Numerical Columns:
# Index(['Farm_Area_Hectares', 'Rainfall_mm', 'Avg_Temperature_C',
#        'Humidity_pct', 'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct',
#        'Nitrogen_kg_ha', 'Phosphorus_kg_ha', 'Potassium_kg_h',
#        'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score',
#        'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne',
#        'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3',
#        'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct'],
#       dtype='object')
#
# Categorical Columns:
# Index(['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Irrigation_Method'], dtype='object')

# %%
df.nunique() #number of unique values in each column
# Out:
# Farm_ID                          4000
# State                               8
# District                           10
# Crop                                8
# Season                              3
# Farm_Area_Hectares               1370
# Rainfall_mm                      3256
# Avg_Temperature_C                 204
# Humidity_pct                      573
# Sunlight_Hours_Day                 71
# Soil_pH                           313
# Soil_Moisture_pct                 343
# Nitrogen_kg_ha                   1229
# Phosphorus_kg_ha                  760
# Potassium_kg_h                   1137
# Irrigation_Method                   4
# Fertilizer_kg_ha                 1881
# Pesticide_Litre_ha                851
# Seed_Quality_Score                 36
# Yield_Tonnes_Ha                   738
# Production_Tonnes                2528
# Market_Price_INR_Tonne           3760
# Total_Cost_INR                   3995
# Revenue_INR                      3993
# Profit_INR                       3992
# ...

# %% [markdown]
# ## 2. Dataset Understanding
#
# The dataset contains 4,000 agricultural farm records and 28 columns.
#
# The data consists of 6 categorical variables and 22 numerical variables. The categorical variables include farm location, crop, season, and irrigation method, while the numerical variables describe environmental conditions, soil characteristics, agricultural inputs, production, economic performance, water usage, and disease/pest risk.
#
# The dataset contains:
# - 8 states
# - 10 districts
# - 8 crops
# - 3 seasons: Kharif, Rabi, and Zaid
# - 4 irrigation methods
#
# The seasonal distribution is uneven, with Kharif having the highest number of records, followed by Rabi and Zaid. Crop records are also distributed unevenly, with Rice having the highest number of observations and Sugarcane the lowest.
#
# The main agricultural performance variables identified for further analysis are Yield_Tonnes_Ha, Production_Tonnes, Revenue_INR, and Profit_INR. Environmental, soil, input, irrigation, and risk variables can be analyzed to understand factors associated with agricultural performance.

# %%
# Check missing values and their percentage

missing_summary = pd.DataFrame({
    "Missing_Values": df.isnull().sum(),
    "Missing_Percentage": (df.isnull().sum() / len(df)) * 100
})

missing_summary = missing_summary[missing_summary["Missing_Values"] > 0]
missing_summary
# Out:
#                    Missing_Values  Missing_Percentage
# Rainfall_mm                    48                 1.2
# Soil_Moisture_pct              40                 1.0
# Yield_Tonnes_Ha                32                 0.8

# %%
missing_rows = df[
    df[["Rainfall_mm", "Soil_Moisture_pct", "Yield_Tonnes_Ha"]]
    .isnull()
    .any(axis=1)
]

print("Number of rows with missing values:", len(missing_rows))

missing_rows.head(20)
# Out:
# Number of rows with missing values: 120
#      Farm_ID           State  District       Crop  Season  Farm_Area_Hectares  \
# 28   SF10029      Tamil Nadu    Rajkot      Maize    Rabi               12.94
# 43   SF10044      Tamil Nadu     Erode      Wheat    Rabi                7.56
# 55   SF10056       Karnataka  Warangal  Groundnut    Rabi               11.70
# 121  SF10122     Maharashtra     Erode     Cotton  Kharif                3.26
# 163  SF10164  Madhya Pradesh     Erode     Pulses    Zaid                3.55
# 186  SF10187      Tamil Nadu    Indore       Rice    Rabi                2.39
# 196  SF10197  Andhra Pradesh   Raichur       Rice  Kharif                4.53
# 253  SF10254      Tamil Nadu  Ludhiana  Sugarcane    Zaid                5.93
# 271  SF10272       Karnataka     Erode  Groundnut  Kharif                6.25
# 272  SF10273          Punjab    Rajkot      Maize    Rabi                9.96
# ...

# %%
# Fill missing numerical values with the median

df["Rainfall_mm"] = df["Rainfall_mm"].fillna(df["Rainfall_mm"].median())

df["Soil_Moisture_pct"] = df["Soil_Moisture_pct"].fillna(
    df["Soil_Moisture_pct"].median()
)

df["Yield_Tonnes_Ha"] = df["Yield_Tonnes_Ha"].fillna(df["Yield_Tonnes_Ha"].median())

# %%
# Verify that the missing values are gone

df[["Rainfall_mm", "Soil_Moisture_pct", "Yield_Tonnes_Ha"]].isnull().sum()
# Out:
# Rainfall_mm          0
# Soil_Moisture_pct    0
# Yield_Tonnes_Ha      0
# dtype: int64

# %%
# Average agricultural performance for each crop

crop_analysis = df.groupby("Crop")[[
    "Yield_Tonnes_Ha",
    "Production_Tonnes",
    "Revenue_INR",
    "Profit_INR"
]].mean().sort_values("Profit_INR", ascending=False)

crop_analysis
# Out:
#            Yield_Tonnes_Ha  Production_Tonnes   Revenue_INR     Profit_INR
# Crop
# Sugarcane        46.642361         392.413016  1.371980e+06  817187.986885
# Chilli            1.542767          12.382888  1.276777e+06  750878.342233
# Cotton            1.229783           9.395866  6.394231e+05  124546.915354
# Groundnut         1.322901           9.655825  5.429355e+05   44858.120283
# Pulses            0.921512           7.401411  5.284659e+05   -4238.052419
# Maize             2.710036          21.781125  4.570680e+05  -83978.326679
# Rice              2.431304          19.288623  4.236153e+05 -102213.504348
# Wheat             2.108013          16.853909  4.001049e+05 -123398.337134

# %%
import matplotlib.pyplot as plt #visulaizse

crop_analysis["Profit_INR"].plot(kind="bar", figsize=(10, 5))

plt.title("Average Profit by Crop")
plt.xlabel("Crop")
plt.ylabel("Average Profit (INR)")
plt.xticks(rotation=45)
plt.show()

# %%
# Average performance by farming season

season_analysis = df.groupby("Season")[[
    "Yield_Tonnes_Ha",
    "Production_Tonnes",
    "Revenue_INR",
    "Profit_INR"
]].mean().sort_values("Profit_INR", ascending=False)

season_analysis
# Out:
#         Yield_Tonnes_Ha  Production_Tonnes    Revenue_INR     Profit_INR
# Season
# Kharif         5.628612          46.311192  710719.055649  178914.647555
# Rabi           5.039435          41.486712  601526.048556   87689.470191
# Zaid           4.641313          38.886111  519171.904040  -24804.824916

# %%
#visulize season by profit
import matplotlib.pyplot as plt
season_analysis["Profit_INR"].plot(kind="bar",figsize=(10,5))
plt.title("Average Profit by Season")
plt.xlabel("Season")
plt.ylabel("Average Profit (INR)")
plt.xticks(rotation=45)
plt.show()

# %%
state_analysis = df.groupby("State")[[
    "Yield_Tonnes_Ha",
    "Production_Tonnes",
    "Revenue_INR",
    "Profit_INR"
]].mean().sort_values("Profit_INR",ascending=False)

state_analysis
# Out:
#                 Yield_Tonnes_Ha  Production_Tonnes    Revenue_INR  \
# State
# Punjab                 6.121116          52.233099  686225.702479
# Maharashtra            5.017480          43.984043  650032.669922
# Karnataka              5.685481          47.732720  653426.182004
# Tamil Nadu             4.875175          40.840371  629093.416495
# Gujarat                5.659016          48.331988  654692.860656
# Telangana              5.044477          39.254186  628784.532946
# Madhya Pradesh         4.989940          37.559517  597558.358149
# Andhra Pradesh         4.628771          36.913157  606663.659735
#
#                    Profit_INR
# State
# Punjab          136025.636364
# Maharashtra     135428.855469
# Karnataka       119422.335378
# Tamil Nadu      117744.748454
# Gujarat         117568.235656
# Telangana       108829.616279
# Madhya Pradesh   86840.756539
# Andhra Pradesh   73453.527410

# %%
import matplotlib.pyplot as plt
state_analysis["Profit_INR"].plot(kind='bar',figsize=(10,5))
plt.title("Average Profit by State")
plt.xlabel("State")
plt.ylabel("Average Profit (INR)")
plt.xticks(rotation=45)
plt.show()

# %%
# Average agricultural performance for each district

district_analysis = df.groupby("District")[[
    "Yield_Tonnes_Ha",
    "Production_Tonnes",
    "Revenue_INR",
    "Profit_INR"
]].mean().sort_values("Profit_INR", ascending=False)

district_analysis
# Out:
#           Yield_Tonnes_Ha  Production_Tonnes    Revenue_INR     Profit_INR
# District
# Warangal         5.503389          46.270711  703386.386256  166449.962085
# Nalgonda         5.801181          47.539566  651104.563855  131125.836145
# Raichur          4.940777          39.281347  637352.417098  125172.699482
# Rajkot           6.020150          54.831671  648998.324190  119463.276808
# Guntur           5.472359          44.621667  635094.217949  116411.417949
# Erode            4.177816          37.773499  630542.699752  102079.565757
# Nashik           4.863881          36.736739  614387.897574   94910.172507
# Indore           4.883240          38.555638  630401.750000   90421.341837
# Ludhiana         5.799883          45.164614  621442.688525   87590.831382
# Krishna          4.847583          40.524122  600329.529262   78240.903308

# %%
import matplotlib.pyplot as plt
district_analysis["Profit_INR"].plot(kind="bar",figsize=(10,5))
plt.title("Average Profit by District")
plt.xlabel("District")
plt.ylabel("Average Profit (INR)")
plt.show()

# %%
# Average agricultural performance for each irrigation method

irrigation_analysis = df.groupby("Irrigation_Method")[[
    "Yield_Tonnes_Ha",
    "Production_Tonnes",
    "Revenue_INR",
    "Profit_INR",
    "Water_Used_m3",
    "Water_Efficiency_t_per_1000m3"
]].mean().sort_values("Profit_INR", ascending=False)

irrigation_analysis
# Out:
#                    Yield_Tonnes_Ha  Production_Tonnes    Revenue_INR  \
# Irrigation_Method
# Drip                      6.577989          57.994284  754571.233880
# Sprinkler                 5.160627          42.337629  617730.301090
# Rainfed                   4.602142          36.605034  584353.977906
# Flood                     4.863977          38.731611  610138.153435
#
#                       Profit_INR  Water_Used_m3  Water_Efficiency_t_per_1000m3
# Irrigation_Method
# Drip               219625.997814    5918.747541                       6.267129
# Sprinkler           91121.079019    6208.258856                       4.669805
# Rainfed             79050.365034    3549.554275                       7.563784
# Flood               73354.022901    8026.472519                       3.438853

# %%
import matplotlib.pyplot as plt
irrigation_analysis["Profit_INR"].plot(kind="bar",figsize=(10,5))
plt.title("Average Profit by Irrigation Method")
plt.xlabel("Irrigation Method")
plt.ylabel("Average Profit (INR)")
plt.show()

# %%
# Select important numerical factors for correlation analysis

correlation_data = df[[
    "Rainfall_mm",
    "Avg_Temperature_C",
    "Humidity_pct",
    "Sunlight_Hours_Day",
    "Soil_Moisture_pct",
    "Nitrogen_kg_ha",
    "Phosphorus_kg_ha",
    "Potassium_kg_h",
    "Fertilizer_kg_ha",
    "Seed_Quality_Score",
    "Yield_Tonnes_Ha"
]]

correlation_data
# Out:
#       Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  \
# 0           486.4               24.3          69.1                 5.8
# 1           855.4               25.7          78.4                 5.1
# 2           455.6               23.9          56.4                10.3
# 3           753.2               29.7          65.2                 6.3
# 4           101.6               34.1          55.2                 6.5
# ...           ...                ...           ...                 ...
# 3995        865.4               27.3          51.4                 6.3
# 3996        947.5               29.2          85.5                 6.1
# 3997         80.0               35.4          68.5                 8.6
# 3998        475.0               28.2          61.7                 6.4
# 3999        984.3               25.8          77.2                 5.9
#
#       Soil_Moisture_pct  Nitrogen_kg_ha  Phosphorus_kg_ha  Potassium_kg_h  \
# ...

# %%
correlation_matrix = correlation_data.corr()

correlation_matrix
# Out:
#                     Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# Rainfall_mm            1.000000           0.198492      0.521069
# Avg_Temperature_C      0.198492           1.000000      0.138136
# Humidity_pct           0.521069           0.138136      1.000000
# Sunlight_Hours_Day    -0.362779          -0.033863     -0.297298
# Soil_Moisture_pct      0.508941           0.084001      0.446470
# Nitrogen_kg_ha         0.007460           0.018707      0.001198
# Phosphorus_kg_ha       0.020940           0.008508     -0.005963
# Potassium_kg_h         0.031373           0.022993     -0.003070
# Fertilizer_kg_ha       0.024602           0.015861      0.024623
# Seed_Quality_Score    -0.018581          -0.031943     -0.045598
# Yield_Tonnes_Ha        0.030951           0.009996      0.012297
#
#                     Sunlight_Hours_Day  Soil_Moisture_pct  Nitrogen_kg_ha  \
# Rainfall_mm                  -0.362779           0.508941        0.007460
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Matrix of Agricultural Factors")
plt.show()

# %%
df["Profit_INR"].describe()
# Out:
# count    4.000000e+03
# mean     1.115565e+05
# std      5.450819e+05
# min     -1.019223e+06
# 25%     -1.487318e+05
# 50%      3.673000e+03
# 75%      2.161878e+05
# max      4.345421e+06
# Name: Profit_INR, dtype: float64

# %%
df["Profit_INR"].plot(kind="box", figsize=(8, 5))

plt.title("Distribution of Profit")
plt.ylabel("Profit (INR)")
plt.show()

# %%
Q1 = df["Profit_INR"].quantile(0.25)
Q3 = df["Profit_INR"].quantile(0.75)

Q1, Q3
# Out:
# (np.float64(-148731.75), np.float64(216187.75))

# %%
IQR = Q3 - Q1

IQRIQR = Q3 - Q1

IQR
# Out:
# np.float64(364919.5)

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

lower_bound, upper_bound
# Out:
# (np.float64(-696111.0), np.float64(763567.0))

# %%
outliers = df[
    (df["Profit_INR"] < lower_bound) |
    (df["Profit_INR"] > upper_bound)
]

outliers
# Out:
#       Farm_ID           State  District       Crop  Season  \
# 9     SF10010      Tamil Nadu   Raichur     Chilli    Rabi
# 30    SF10031       Telangana  Nalgonda     Chilli    Rabi
# 61    SF10062       Karnataka  Ludhiana     Cotton    Rabi
# 75    SF10076     Maharashtra    Guntur  Sugarcane  Kharif
# 78    SF10079  Madhya Pradesh  Nalgonda     Chilli    Rabi
# ...       ...             ...       ...        ...     ...
# 3964  SF13965       Telangana  Nalgonda     Chilli  Kharif
# 3967  SF13968      Tamil Nadu  Ludhiana      Maize  Kharif
# 3975  SF13976  Andhra Pradesh    Guntur     Chilli    Rabi
# 3983  SF13984         Gujarat    Nashik     Chilli  Kharif
# 3996  SF13997       Karnataka   Krishna     Chilli  Kharif
#
#       Farm_Area_Hectares  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# 9                  13.69        415.8               22.3          57.3
# 30                 11.96        284.2               24.1          62.1
# ...

# %%
negative_outliers = df[df["Profit_INR"] < lower_bound]

positive_outliers = df[df["Profit_INR"] > upper_bound]

print("Negative outliers:", len(negative_outliers))
print("Positive outliers:", len(positive_outliers))
# Out:
# Negative outliers: 51
# Positive outliers: 353

# %%
positive_outliers[[
    "State",
    "District",
    "Crop",
    "Season",
    "Farm_Area_Hectares",
    "Production_Tonnes",
    "Market_Price_INR_Tonne",
    "Total_Cost_INR",
    "Revenue_INR",
    "Profit_INR"
]].head(10)
# Out:
#               State  District       Crop  Season  Farm_Area_Hectares  \
# 9        Tamil Nadu   Raichur     Chilli    Rabi               13.69
# 30        Telangana  Nalgonda     Chilli    Rabi               11.96
# 61        Karnataka  Ludhiana     Cotton    Rabi               14.23
# 75      Maharashtra    Guntur  Sugarcane  Kharif               10.64
# 78   Madhya Pradesh  Nalgonda     Chilli    Rabi               10.00
# 87   Madhya Pradesh  Warangal     Chilli  Kharif                5.72
# 88   Andhra Pradesh   Raichur     Chilli  Kharif               13.29
# 92          Gujarat    Guntur  Sugarcane  Kharif               12.74
# 110     Maharashtra  Ludhiana     Pulses  Kharif               13.42
# 113      Tamil Nadu    Rajkot  Sugarcane    Rabi               14.35
#
#      Production_Tonnes  Market_Price_INR_Tonne  Total_Cost_INR  Revenue_INR  \
# 9                31.35                   94383         1004072      2958907
# ...

# %%
negative_outliers[[
    "State",
    "District",
    "Crop",
    "Season",
    "Farm_Area_Hectares",
    "Production_Tonnes",
    "Market_Price_INR_Tonne",
    "Total_Cost_INR",
    "Revenue_INR",
    "Profit_INR"
]].head(10)
# Out:
#               State  District       Crop  Season  Farm_Area_Hectares  \
# 104         Gujarat   Krishna      Wheat    Zaid               12.30
# 156          Punjab  Ludhiana  Sugarcane  Kharif               14.42
# 165  Andhra Pradesh     Erode      Wheat  Kharif               13.10
# 351          Punjab    Indore       Rice  Kharif               12.73
# 564  Andhra Pradesh  Warangal       Rice  Kharif               13.93
# 585       Telangana  Warangal     Cotton    Zaid               13.96
# 650         Gujarat   Raichur      Maize    Rabi               13.23
# 705       Karnataka   Krishna      Maize    Rabi               14.94
# 780  Andhra Pradesh  Ludhiana  Groundnut    Rabi               14.64
# 820  Andhra Pradesh    Rajkot       Rice    Zaid               13.97
#
#      Production_Tonnes  Market_Price_INR_Tonne  Total_Cost_INR  Revenue_INR  \
# 104               3.69                   26773         1063989        98792
# ...

# %%
df["Yield_Tonnes_Ha"].describe()
# Out:
# count    4000.000000
# mean        5.242350
# std        13.311549
# min         0.300000
# 25%         1.050000
# 50%         1.740000
# 75%         2.830000
# max       101.440000
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
yield_by_crop = df.groupby("Crop")["Yield_Tonnes_Ha"].mean().sort_values(ascending=False)

yield_by_crop
# Out:
# Crop
# Sugarcane    46.642361
# Maize         2.710036
# Rice          2.431304
# Wheat         2.108013
# Chilli        1.542767
# Groundnut     1.322901
# Cotton        1.229783
# Pulses        0.921512
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
import matplotlib.pyplot as plt
yield_by_crop.plot(kind="bar",figsize=(10,5))
plt.title("Average Yield by Crop")
plt.xlabel("Crop")
plt.ylabel("Average Yield (Tonnes/Hectare)")
plt.show()

# %%
yield_by_district = df.groupby("District")["Yield_Tonnes_Ha"].mean().sort_values(ascending=False)

yield_by_district
# Out:
# District
# Rajkot      6.020150
# Nalgonda    5.801181
# Ludhiana    5.799883
# Warangal    5.503389
# Guntur      5.472359
# Raichur     4.940777
# Indore      4.883240
# Nashik      4.863881
# Krishna     4.847583
# Erode       4.177816
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
import matplotlib.pyplot as plt
yield_by_district.plot(kind="bar",figsize=(10,5))
plt.title("Average Yield by District")
plt.xlabel("District")
plt.ylabel("Average Yield (Tonnes/Hectare)")
plt.show()

# %%
yield_by_season = df.groupby("Season")["Yield_Tonnes_Ha"].mean().sort_values(ascending=False)

yield_by_season
# Out:
# Season
# Kharif    5.628612
# Rabi      5.039435
# Zaid      4.641313
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
financial_by_crop = df.groupby("Crop")[[
    "Total_Cost_INR",
    "Revenue_INR",
    "Profit_INR"
]].mean().sort_values("Profit_INR", ascending=False)

financial_by_crop
# Out:
#            Total_Cost_INR   Revenue_INR     Profit_INR
# Crop
# Sugarcane   554792.127869  1.371980e+06  817187.986885
# Chilli      525898.885922  1.276777e+06  750878.342233
# Cotton      514876.167323  6.394231e+05  124546.915354
# Groundnut   498077.377358  5.429355e+05   44858.120283
# Pulses      532703.919355  5.284659e+05   -4238.052419
# Maize       541046.317604  4.570680e+05  -83978.326679
# Rice        525828.763768  4.236153e+05 -102213.504348
# Wheat       523503.223127  4.001049e+05 -123398.337134

# %%
financial_by_crop["Profit_INR"].plot(kind="bar", figsize=(10, 5))

plt.title("Average Profit by Crop")
plt.xlabel("Crop")
plt.ylabel("Average Profit (INR)")
plt.xticks(rotation=45)
plt.axhline(0, linewidth=1) #distinguish the profit one above and negative bar down
plt.show()

# %%
#AVERAGE PROFIT BY STATE
state_analysis = df.groupby("State")[[
    "Yield_Tonnes_Ha",
    "Profit_INR"
]].mean().sort_values("Profit_INR", ascending=False)

state_analysis
# Out:
#                 Yield_Tonnes_Ha     Profit_INR
# State
# Punjab                 6.121116  136025.636364
# Maharashtra            5.017480  135428.855469
# Karnataka              5.685481  119422.335378
# Tamil Nadu             4.875175  117744.748454
# Gujarat                5.659016  117568.235656
# Telangana              5.044477  108829.616279
# Madhya Pradesh         4.989940   86840.756539
# Andhra Pradesh         4.628771   73453.527410

# %%
#AVERAGE PROFIT BY STATE
state_analysis["Profit_INR"].plot(kind="bar", figsize=(10, 5))

plt.title("Average Profit by State")
plt.xlabel("State")
plt.ylabel("Average Profit (INR)")
plt.xticks(rotation=45)
plt.show()

# %%
#Average yield by state
state_analysis["Yield_Tonnes_Ha"].plot(kind="bar", figsize=(10, 5))

plt.title("Average Yield by State")
plt.xlabel("State")
plt.ylabel("Average Yield (Tonnes/Hectare)")
plt.xticks(rotation=45)
plt.show()

# %%
profit_by_district = df.groupby("District")["Profit_INR"].mean().sort_values(ascending=False)

profit_by_district
# Out:
# District
# Warangal    166449.962085
# Nalgonda    131125.836145
# Raichur     125172.699482
# Rajkot      119463.276808
# Guntur      116411.417949
# Erode       102079.565757
# Nashik       94910.172507
# Indore       90421.341837
# Ludhiana     87590.831382
# Krishna      78240.903308
# Name: Profit_INR, dtype: float64

# %%
#Average Profit by District
profit_by_district.plot(kind="bar", figsize=(10, 5))

plt.title("Average Profit by District")
plt.xlabel("District")
plt.ylabel("Average Profit (INR)")
plt.xticks(rotation=45)
plt.axhline(0, linewidth=1)
plt.show()

# %% [markdown]
# ⬇Water efficiency

# %%
water_by_crop = df.groupby("Crop")[
    "Water_Efficiency_t_per_1000m3"
].mean().sort_values(ascending=False)

water_by_crop
# Out:
# Crop
# Sugarcane    30.477672
# Maize         5.602995
# Wheat         4.628393
# Groundnut     3.154795
# Chilli        2.947709
# Pulses        2.896504
# Rice          1.946112
# Cotton        1.938016
# Name: Water_Efficiency_t_per_1000m3, dtype: float64

# %%
#Average Water Efficiency by Crop
water_by_crop.plot(kind="bar", figsize=(10, 5))

plt.title("Average Water Efficiency by Crop")
plt.xlabel("Crop")
plt.ylabel("Water Efficiency (Tonnes per 1000 m³)")
plt.xticks(rotation=45)
plt.show()

# %%
risk_by_crop = df.groupby("Crop")["Disease_Pest_Risk_pct"].mean().sort_values(ascending=False)

risk_by_crop
# Out:
# Crop
# Wheat        47.854723
# Pulses       46.570161
# Rice         46.495797
# Groundnut    46.289151
# Chilli       46.062136
# Cotton       45.974606
# Maize        45.539564
# Sugarcane    45.403934
# Name: Disease_Pest_Risk_pct, dtype: float64

# %%
risk_by_crop.plot(kind="bar", figsize=(10, 5))
plt.title("Average Disease & Pest Risk by Crop")
plt.xlabel("Crop")
plt.ylabel("Average Risk (%)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **Correlation Analysis.**

# %%
correlation_matrix = df.corr(numeric_only=True)

correlation_matrix
# Out:
#                                Farm_Area_Hectares  Rainfall_mm  \
# Farm_Area_Hectares                       1.000000     0.007256
# Rainfall_mm                              0.007256     1.000000
# Avg_Temperature_C                        0.036870     0.198492
# Humidity_pct                             0.000471     0.521069
# Sunlight_Hours_Day                       0.001821    -0.362779
# Soil_pH                                  0.009857     0.016657
# Soil_Moisture_pct                        0.004033     0.508941
# Nitrogen_kg_ha                           0.013658     0.007460
# Phosphorus_kg_ha                        -0.006625     0.020940
# Potassium_kg_h                           0.000195     0.031373
# Fertilizer_kg_ha                         0.014975     0.024602
# Pesticide_Litre_ha                      -0.005207     0.004058
# Seed_Quality_Score                       0.015236    -0.018581
# Yield_Tonnes_Ha                          0.030203     0.030951
# ...

# %%
yield_correlation = correlation_matrix["Yield_Tonnes_Ha"].sort_values(ascending=False)

yield_correlation
# Out:
# Yield_Tonnes_Ha                  1.000000
# Water_Efficiency_t_per_1000m3    0.912568
# Production_Tonnes                0.882813
# Profit_INR                       0.488466
# Revenue_INR                      0.432152
# Water_Used_m3                    0.386294
# Nitrogen_kg_ha                   0.053149
# Phosphorus_kg_ha                 0.047941
# Rainfall_mm                      0.030951
# Total_Cost_INR                   0.030622
# Farm_Area_Hectares               0.030203
# Disease_Pest_Risk_pct            0.014292
# Humidity_pct                     0.012297
# Soil_Moisture_pct                0.010999
# Avg_Temperature_C                0.009996
# Potassium_kg_h                   0.003382
# Fertilizer_kg_ha                 0.000018
# Seed_Quality_Score              -0.007209
# Pesticide_Litre_ha              -0.007779
# Sunlight_Hours_Day              -0.015341
# Soil_pH                         -0.020672
# Market_Price_INR_Tonne          -0.382607
# ...

# %%
#PROFIT CORREALTION WITH OTHER
profit_correlation = correlation_matrix["Profit_INR"].sort_values(ascending=False)

profit_correlation
# Out:
# Profit_INR                       1.000000
# Revenue_INR                      0.887331
# Production_Tonnes                0.554172
# Water_Efficiency_t_per_1000m3    0.489487
# Yield_Tonnes_Ha                  0.488466
# Market_Price_INR_Tonne           0.225119
# Water_Used_m3                    0.190278
# Farm_Area_Hectares               0.115241
# Rainfall_mm                      0.107648
# Soil_Moisture_pct                0.091281
# Nitrogen_kg_ha                   0.085016
# Total_Cost_INR                   0.068356
# Disease_Pest_Risk_pct            0.067583
# Humidity_pct                     0.063775
# Phosphorus_kg_ha                 0.049747
# Potassium_kg_h                   0.031192
# Seed_Quality_Score               0.010438
# Avg_Temperature_C                0.009043
# Soil_pH                         -0.013145
# Pesticide_Litre_ha              -0.025705
# Sunlight_Hours_Day              -0.054822
# Fertilizer_kg_ha                -0.073542
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap of Agricultural Variables")
plt.show()

# %%
# Key insights from the analysis

print("1. Best performing crop by average profit:", financial_by_crop["Profit_INR"].idxmax())
print("2. Lowest performing crop by average profit:", financial_by_crop["Profit_INR"].idxmin())

print("3. Highest yielding state:", state_analysis["Yield_Tonnes_Ha"].idxmax())
print("4. Lowest yielding state:", state_analysis["Yield_Tonnes_Ha"].idxmin())

print("5. Highest water-efficient crop:", water_by_crop.idxmax())
print("6. Lowest water-efficient crop:", water_by_crop.idxmin())

print("7. Highest disease & pest risk crop:", risk_by_crop.idxmax())
print("8. Lowest disease & pest risk crop:", risk_by_crop.idxmin())
# Out:
# 1. Best performing crop by average profit: Sugarcane
# 2. Lowest performing crop by average profit: Wheat
# 3. Highest yielding state: Punjab
# 4. Lowest yielding state: Andhra Pradesh
# 5. Highest water-efficient crop: Sugarcane
# 6. Lowest water-efficient crop: Cotton
# 7. Highest disease & pest risk crop: Wheat
# 8. Lowest disease & pest risk crop: Sugarcane

# %% [markdown]
# ### Key Findings and Recommendations
# # Key Findings
# - Sugarcane achieved the highest average profit.
# - Wheat recorded the lowest average profit.
# - Punjab had the highest average yield among the states.
# - Andhra Pradesh had the lowest average yield.
# - Sugarcane showed the highest water efficiency.
# - Cotton showed the lowest water efficiency.
# - Wheat had the highest disease and pest risk.
# - Sugarcane had the lowest disease and pest risk.
# #### Recommendations
# - Focus on high-performing crops such as Sugarcane where conditions are suitable.
# - Investigate the factors contributing to Punjab's higher average yield.
# - Improve agricultural practices in lower-yielding regions.
# - Improve water-management practices for crops with lower water efficiency.
# - Give greater attention to disease and pest management for high-risk crops such as Wheat.
# - Use profitability, yield, water efficiency, and risk together when selecting crops.

# %%
# Final summary of major findings

final_summary = {
    "Best Profit Crop": financial_by_crop["Profit_INR"].idxmax(),
    "Lowest Profit Crop": financial_by_crop["Profit_INR"].idxmin(),
    "Highest Yield State": state_analysis["Yield_Tonnes_Ha"].idxmax(),
    "Lowest Yield State": state_analysis["Yield_Tonnes_Ha"].idxmin(),
    "Most Water Efficient Crop": water_by_crop.idxmax(),
    "Least Water Efficient Crop": water_by_crop.idxmin(),
    "Highest Risk Crop": risk_by_crop.idxmax(),
    "Lowest Risk Crop": risk_by_crop.idxmin()
}

final_summary
# Out:
# {'Best Profit Crop': 'Sugarcane',
#  'Lowest Profit Crop': 'Wheat',
#  'Highest Yield State': 'Punjab',
#  'Lowest Yield State': 'Andhra Pradesh',
#  'Most Water Efficient Crop': 'Sugarcane',
#  'Least Water Efficient Crop': 'Cotton',
#  'Highest Risk Crop': 'Wheat',
#  'Lowest Risk Crop': 'Sugarcane'}

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# 1. Average Profit by Crop
financial_by_crop["Profit_INR"].plot(
    kind="bar",
    ax=axes[0, 0]
)
axes[0, 0].set_title("Average Profit by Crop")
axes[0, 0].set_xlabel("Crop")
axes[0, 0].set_ylabel("Average Profit (INR)")
axes[0, 0].tick_params(axis="x", rotation=45)

# 2. Average Yield by State
state_analysis["Yield_Tonnes_Ha"].plot(
    kind="bar",
    ax=axes[0, 1]
)
axes[0, 1].set_title("Average Yield by State")
axes[0, 1].set_xlabel("State")
axes[0, 1].set_ylabel("Average Yield (Tonnes/Hectare)")
axes[0, 1].tick_params(axis="x", rotation=45)

# 3. Water Efficiency by Crop
water_by_crop.plot(
    kind="bar",
    ax=axes[1, 0]
)
axes[1, 0].set_title("Average Water Efficiency by Crop")
axes[1, 0].set_xlabel("Crop")
axes[1, 0].set_ylabel("Tonnes per 1000 m³")
axes[1, 0].tick_params(axis="x", rotation=45)

# 4. Disease & Pest Risk by Crop
risk_by_crop.plot(
    kind="bar",
    ax=axes[1, 1]
)
axes[1, 1].set_title("Average Disease & Pest Risk by Crop")
axes[1, 1].set_xlabel("Crop")
axes[1, 1].set_ylabel("Risk (%)")
axes[1, 1].tick_params(axis="x", rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Conclusion
#
# This project analyzed seasonal agricultural performance using crop, state, financial, water-efficiency, and disease/pest-risk data.
#
# The analysis found that Sugarcane had the highest average profit and the highest water efficiency among the crops. Punjab recorded the highest average yield among the states, while Andhra Pradesh had the lowest average yield.
#
# The analysis also showed that Wheat had the highest average disease and pest risk and the lowest average profit. Cotton recorded the lowest water efficiency.
#
# Overall, the results show that agricultural performance depends on multiple factors including crop selection, location, profitability, water usage, yield, and disease/pest risk. Considering these factors together can help support better agricultural planning and resource management.
#
# ## Project Outcome
#
# The analysis successfully identified:
# - High- and low-performing crops
# - High- and low-yielding states
# - Crop profitability patterns
# - Water-efficiency differences
# - Disease and pest risk patterns
# - Important relationships between agricultural variables using correlation analysis

# %% [markdown]
# # Project Workflow
#
# 1. Loaded the agricultural dataset
# 2. Inspected dataset structure and statistics
# 3. Identified and handled missing values
# 4. Analyzed crop performance
# 5. Analyzed seasonal performance
# 6. Compared state-level performance
# 7. Analyzed financial performance
# 8. Analyzed water efficiency
# 9. Analyzed disease and pest risk
# 10. Performed correlation analysis
# 11. Identified key findings and recommendations
# 12. Created visualizations and a final dashboard
